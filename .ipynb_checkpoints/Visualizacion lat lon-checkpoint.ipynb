# %%
#manipulacion de datos 
import geopandas as gpd
import pandas as pd
import numpy as np
from scipy import stats


#visualizacion 
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set_style('darkgrid')

#visualizacion de mapa.
import contextily as ctx


#utiles
import datetime
import functools
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data = pd.read_csv("data_encuesta.csv")
data
# Out:
#    Unnamed: 0                                form  userid  question  \
# 0           2  Â¿CÃ³mo contribuyo con la equidad?     2.0       2.0
# 1           3  Â¿CÃ³mo contribuyo con la equidad?     2.0       1.0
# 2           4  Â¿CÃ³mo contribuyo con la equidad?     1.0       0.0
# 3           5  Â¿CÃ³mo contribuyo con la equidad?     1.0       3.0
# 4           6  Â¿CÃ³mo contribuyo con la equidad?     1.0       2.0
# 5           7  Â¿CÃ³mo contribuyo con la equidad?     1.0       1.0
#
#       answer       long        lat                  datetime
# 0        esi -73.241655 -39.810613  2019-12-13T00:38:07.851Z
# 1  otra cosa -73.241655 -39.810613  2019-12-13T00:38:07.851Z
# 2      ddsds -73.224778 -39.827259  2019-12-12T23:33:38.876Z
# 3       dddd -73.224778 -39.827259  2019-12-12T23:33:38.876Z
# 4        ssd -73.224778 -39.827259  2019-12-12T23:33:38.876Z
# 5        aaa -73.224778 -39.827259  2019-12-12T23:33:38.876Z

# %%
#Censo con geometria
df_MINDC17 = gpd.read_file("Censo2017_16R_ManzanaEntidad_CSV/Censo2017_Identificación_Geográfica/R14/MANZANA_IND_C17.shp")
print(df_MINDC17.keys())
#Se filtra comuna valdivia = 14101
df_MINDC17 = df_MINDC17[df_MINDC17['COMUNA']=='14101']
df_MINDC17.head()
# Out:
# Index(['REGION', 'NOM_REGION', 'PROVINCIA', 'NOM_PROVIN', 'COMUNA',
#        'NOM_COMUNA', 'DISTRITO', 'LOC_ZON', 'ENT_MAN', 'CATEGORIA',
#        'NOM_CATEGO', 'MANZENT_I', 'TOTAL_PERS', 'TOTAL_VIVI', 'SHAPE_Leng',
#        'SHAPE_Area', 'geometry'],
#       dtype='object')
#   REGION          NOM_REGION PROVINCIA NOM_PROVIN COMUNA NOM_COMUNA  DISTRITO  \
# 0     14  REGIÓN DE LOS RÍOS       141   VALDIVIA  14101   VALDIVIA         4
# 1     14  REGIÓN DE LOS RÍOS       141   VALDIVIA  14101   VALDIVIA         5
# 2     14  REGIÓN DE LOS RÍOS       141   VALDIVIA  14101   VALDIVIA         4
# 3     14  REGIÓN DE LOS RÍOS       141   VALDIVIA  14101   VALDIVIA         4
# 4     14  REGIÓN DE LOS RÍOS       141   VALDIVIA  14101   VALDIVIA         4
#
#    LOC_ZON  ENT_MAN  CATEGORIA NOM_CATEGO       MANZENT_I  TOTAL_PERS  \
# 0        5        3          1         CD  14101041005003         610
# 1        1      801          1         CD  14101051001801          30
# ...

# %%
#DE CSV A PUNTOS EN COMO GEOPANDAS
gdf = gpd.GeoDataFrame(
    data, geometry=gpd.points_from_xy(data.long, data.lat))

# %%
fig, ax = plt.subplots(figsize=(20, 10), dpi=80)
bx = df_MINDC17.plot(column='DISTRITO', 
               ax=ax, 
               legend=True, cmap='tab20c')

gdf.plot(ax=ax, color='red')
